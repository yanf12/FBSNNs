# %%
from FBSNN_pytorch_modified_basket import neural_net
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
Xi = torch.from_numpy(np.array([1.0, 1.0] * int(10 / 2))[None, :]).float()
Xi.requires_grad =True
T = 1.0
M = 30

# %%
Xi
fn_u = neural_net(pathbatch=M, n_dim=10 + 1, n_output=1)

# %%
X = torch.cat([Xi] * M)
t=torch.zeros((M,1),requires_grad=True)
inputs = torch.cat([t, X], dim=1)
u = fn_u.forward(inputs)
DuDx = torch.autograd.grad(torch.sum(u), inputs, retain_graph=True,create_graph=True)[0]  # M x D
print(DuDx.shape)
# Out:
# torch.Size([30, 11])

# %%
H = torch.autograd.functional.hessian(lambda x: fn_u.forward(x)[0], inputs[0,:],create_graph=True)

# %%
H
# Out:
# tensor([[-3.2094e-03, -5.7145e-04,  1.8066e-03,  3.1883e-04, -1.0848e-03,
#          -1.1141e-03,  1.9433e-04,  1.5178e-04,  1.8198e-03,  6.2048e-04,
#          -1.9832e-04],
#         [-5.7145e-04, -1.2599e-03, -3.3925e-04,  1.6227e-03, -1.1364e-03,
#          -5.1150e-04, -4.0920e-04,  4.5107e-04,  7.8602e-04,  2.0874e-03,
#           1.0418e-03],
#         [ 1.8066e-03, -3.3925e-04,  3.2187e-04,  3.6536e-03,  2.2683e-03,
#          -1.5317e-03,  6.3343e-04, -2.3596e-03,  2.1047e-03, -1.0988e-03,
#           1.0541e-03],
#         [ 3.1883e-04,  1.6227e-03,  3.6536e-03, -6.1239e-04,  9.7884e-04,
#           9.4154e-04,  1.5923e-03,  9.2297e-04,  3.1051e-03,  1.4411e-03,
#           1.3919e-03],
#         [-1.0848e-03, -1.1364e-03,  2.2683e-03,  9.7884e-04, -1.4056e-05,
#           1.0853e-03,  8.5163e-04, -1.8962e-04, -2.4416e-06,  4.3583e-04,
#           4.4568e-04],
#         [-1.1141e-03, -5.1150e-04, -1.5317e-03,  9.4154e-04,  1.0853e-03,
# ...

# %%
torch.autograd.grad(DuDx[0,0], X, retain_graph=True,create_graph=True)[0]
# Out:
# tensor([[-0.0006,  0.0018,  0.0003, -0.0011, -0.0011,  0.0002,  0.0002,  0.0018,
#           0.0006, -0.0002],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
# ...
